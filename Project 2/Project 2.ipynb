# %% [markdown]
# ## Project # 2
#
# Create a Multiprocessing, Threaded and Asynchronous application that will calculate the highest prime number in 3 min.
#
# You must start a 0
#
# After you have created these programs analyze  the performance of each. IE: How long did it take to find prime number? Compare each prime and why each found that prime number.
#
# If you wish you can calculate any other non dependent item and them perform analyses.
#
# For code consistancy use the following is_prime function.
# ```python
# def is_prime(n):
#     if n <= 1:
#         return False
#     for i in range(2, int(n ** 0.5) + 1):
#         if n % i == 0:
#             return False
#     return True
# ```
#     async       13,386,001
#     threaded(2) 10,747,921

# %%
def getStuff (Lists):
    list1 = []
    for List in Lists:
        if (Lists[0] == 4):
            list1.append(List)
    return list1

# %%
getStuff([1,2,3,4,5])
# Out:
# []

# %%
a = 1
for i in range(a,4):
    print(i)

    print(i)
# Out:
# 1
# 1
# 2
# 2
# 3
# 3

# %% [markdown]
# # Joanna Escobar
# ## Project 2

# %% [markdown]
# I had issues running multiprocessing and threading in a Jupyter Notebook, so the work is done in the three python script files in this folder. They are named:
# - Project_2_Multiprocessing
# - Project_2_Threading
# - Project_2_Asynchronous

# %% [markdown]
# ### Multiprocessing
#
# #### _Project_2_Multiprocessing.py_
#
# I came across some issues when trying to find the value using Multiprocessing.
#
# I had a tough time trying to keep my processor from getting overwhelmed. While my code would run, and would be able to recieve and store the boolean values that would come from the is_prime function, the processses would quickly become too much for my laptop. I believe this was because it would create a new process for every single numerical value. This was too much, so I tried to mitigate this.
#
# I tried to mitigate this by implementing a ```pool()``` function and parent/child functionality, but I had a few issues with them.
#
# - How to implement the ```pool()``` function when I didn't know how large the largest prime would actually get, as well as how to keep the function working while the prime numbers were being calculated. I used a timing function for the latter, but the former was tricky. I ended up just creating a variable with a huge numerical value I would try to get to (but most likely not be able to) before the end of the three minutes.
# - How to implement ways to get the ```pool()``` and parent/child to talk to each other. I set up the function, but wasn't sure how to get them to work together, and if the parent/child functionality was something I even needed with the ```pool()``` function already there.
#
# I was eventually able to get the multiprocessing file to work by itself, before integrating Threading or Asynchronous, but the starting value had to start at one, rather than at zero to get it to work.
#
# Largest Prime: `63601061`

# %% [markdown]
# ### Threading
#
# #### _Project_2_Threading.py_
#
# I started the Threading assignment much like the Multiprocessing assignment. I used the ```is_prime()``` function for consistency with the other code.
#
# The ```worker()``` and ```threaded_pool()``` functions are taken for Mr. Power's lecture notes and modified to apply to the ```is_prime()``` function rather than the ```fetch_rate()``` function.
#
# The while loop is in place to make sure that the ```threaded_pool()``` function doesn't execute for longer than 3 minutes, as that was the time frame we were given for this project.
#
# It was at this point that I realized that I had misinterpreted the assignment. Instead of comparing the ```is_prime()``` function through three methods, i was supposed to do three different things with the three methods; is_prime(), fibbonnaci, and factorials. I changed my code to better reflect the assignment. I had to do some massive overhauls, like getting rid of the worker() function, although I just commented it out to make sure I still had it if I needed it. Which, it turned out, I did in order to keep the function going.

# %% [markdown]
# ### Asychronous
#
# #### _Project_2_Asynchronous.py_
#
# The Asynchronous file also has the ```is_prime()``` function to allow us to compare the different methods.
#
# I took code from Mr. Power's Lecture 13 in order to set up and start the Asynch functions and get them running.
#
# Issues
# - I did have a few unexpected issues with setting up the ending time for the circuit. When I tried to run the code it at first said that it was unable to add the ```time.time()``` value with an integer value. However, once I closed and opened the program again, I no longer had that issue.
# - The final value of the function would not print. I had a value and print statement set up, but it appears that the placement of the print statement was causing some issues.
#
# It was at this point that I realized that I had misinterpreted the assignment. Instead of comparing the ```is_prime()``` function through three methods, i was supposed to do three different things with the three methods; is_prime(), fibbonnaci, and factorials. I changed my code to better reflect the assignment.
# - I think that I did fairly well at this change, and tried to update my code to what was needed. It was slightly easier for the Asynch file than for the Threading file, as the Asynch file I made was not quite as involved. I did, however, need to find a different way to display the end result.

# %% [markdown]
# ### Testing

# %% [markdown]
# I connected the three files together by importing them in each other's files. In doing so, I realized that they were (at least partially) unable to carry the value of the largest prime over. So, I decided that I would migrate the Threading and Asynchronous code over to Multiprocessing.
