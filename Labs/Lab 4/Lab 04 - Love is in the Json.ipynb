# %% [markdown]
# # Valentine's Day Lab Assignment
# Picking a Romantic Movie
#
# ## Instructions:
# 1. Download a dataset of romantic movies from a public dataset repository (e.g., Kaggle).
#    - Example dataset: "Romantic Movies Dataset" (ensure it's in JSON format).
# 2. Load the dataset from the JSON file.
# 3. Create a function that helps pick a romantic movie based on user preferences.
# 4. Display the selected movie details.
# 5. Verify the JSON file content

# %%
# Sample Code:
min_rating = float(input("Enter the minimum rating (0-10): "))
max_year = int(input("Enter the latest release year: "))

selected_movie = pick_movie(data, min_rating, max_year)

if isinstance(selected_movie, str):
    print(selected_movie)
else:
    print(f"Selected Movie: {selected_movie['Title']}")
    print(f"Year: {selected_movie['Year']}")
    print(f"Rating: {selected_movie['Rating']}")
    print(f"Box Office: ${selected_movie['BoxOffice']} million")

# %% [markdown]
# # Joanna Escobar

# %%
#Joanna Escobar - could not find a json file of romantic movies on kaggle, so went with TV shows on Netflix
#data courtesy of kaggle (Akash Guna and sidhartha reddy)
# https://www.kaggle.com/datasets/akashguna/netflix-prize-shows-information/data

import json

#format taken from notes
with open('imdb.json') as f:
    shows = json.load(f)
print(json.dumps(shows, indent=2))

# %%
#user inputs to be used later
title = input("Enter a title, or '-1' to move on: ")
min_rating = float(input("Enter the minimum rating (0-10)  or '-1' to move on: "))
max_year = int(input("Enter the latest release year, or '-1' to move on: "))
format = input("Enter a format, or '-1' to move on: ")
genre = input("Enter a genre, or '-1' to move on: ")

# %%
#going through json file as stored in 'shows'
print(shows)

# for identifiers in shows:
#     print(identifiers["title"])
#     # for examples in identifiers:#['examples']:
#     #     print(f' {examples}')

# %%
#going through json file as stored in 'shows'
for identifiers in shows:
    print(f'{identifiers}:')
    for examples in identifiers[examples]:#[0]:
        print(f' {examples}')
