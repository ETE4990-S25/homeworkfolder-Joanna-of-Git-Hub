# %% [markdown]
# Your name goes here Pleaese

# %% [markdown]
# ## Objective:
# The objective of this assignment is to practice using Functional Programing.
#
# ## Instructions:
#
# Using everything we learned to day about Functional Programing, lambda and itters create one of each of the following:
# -  Basic Lambda Function
#     - Create a lambda function that takes one arguments and returns even or odd.
# - Advanced lambda Function
#     - Create a lambda function that takes a list and returns their sum
# - Sorting with Lambda
# - Filtering with Lambda - `filter()`
# - Mapping with Lambda - `map()`
# - Reducing with Lambda -  `reduce()`
# - Enumerate with or without Lambda - `enumerate()`
# - zip with or without lambda (may combine enumerate like in class) - `zip()`
#
# Submit the file as a .py

# %% [markdown]
# ### Joanna Escobar

# %%
# Basic Lambda Function (even/odd)
(lambda x: print("Even") if x%2==0 else print("Odd"))(7)
# Out:
# Odd

# %%
# Advanced Lambda Function (return sum of list)
example_list = [1, 2, 3]
abc = 0

x=(lambda a, sum_it: (x+sum_it for x in a))(example_list, abc)
print(x)

# for index in example_list:
#     total_sum = total_sum + index


# my_list = [1, 2, 3, 4, 5]

# for item in my_list:
#     print(item)
# Out:
# <generator object <lambda>.<locals>.<genexpr> at 0x000001B2F39A3100>

# %%
#sorting with lambda. still working on it
alist = [769, 7953, 9828, 6431, 8442, 9878, 6213, 2207]


s = (lambda x: sorted(x))(alist) #couldn't figure out how to get the definition to work
print(list(s))

# def sort_list(list_in):
#     highest_number = 0
#     prev_number = 0
#     new_list = []

#     for i in list_in:
#         if i > highest_number & i != prev_number:
#             highest_number = i
        
#         prev_number = i
#         new_list.append(i)

#     return new_list

# a = sort_list(alist)
# print(a)
# Out:
# [769, 2207, 6213, 6431, 7953, 8442, 9828, 9878]

# %%
#filtering filter()
f = filter(lambda x: x%2==0, range(0,10))
print(list(f))
# Out:
# [0, 2, 4, 6, 8]

# %%
# mapping map()
list_to_add = [1,2,3]

# def square(abc):
#     return abc**2
#
#  map(square, list_to_add)

l = map(lambda y: y**2, list_to_add)
print(list(l))
# Out:
# [1, 4, 9]

# %%
# reducing reduce() still working on it
import functools
xyz = 5

functools.reduce((lambda r: r+5,xyz), range(0,1))
# Out:
# 0

# %%
# enumerating enumerate()
strings = ["first", "second", "third"]

b = enumerate(strings, start = 1)
print(list(b))
# Out:
# [(1, 'first'), (2, 'second'), (3, 'third')]

# %%
# zip()
a = zip(["choice 1", "choice 2", "choice 3"],[1,2,3])
print(list(a))
# Out:
# [('choice 1', 1), ('choice 2', 2), ('choice 3', 3)]
